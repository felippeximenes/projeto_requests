# %% [markdown]
# # Conhecendo a requests

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"44838896223","type":"CreateEvent","actor":{"id":103665518,"login":"Barreratomas","display_login":"Barreratomas","gravatar_id":"","url":"https://api.github.com/users/Barreratomas","avatar_url":"https://avatars.githubusercontent.com/u/103665518?"},"repo":{"id":904361852,"name":"Barreratomas/horarios","url":"https://api.github.com/repos/Barreratomas/horarios"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2024-12-16T18:33:35Z"},{"id":"44838896179","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":898201892,"name":"chongtongTech/chongtongTech","url":"https://api.github.com/repos/chongtongTech/chongtongTech"},"payload":{"repository_id":898201892,"push_id":21735153894,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"ef3e7269ab415664878111fba6a0b0594d62dff3","before":"ba9b0981e57f3c7b0ee0f2803aa10505cb4792b7","commits":[{"sha":"ef3e7269ab415664878111fba6a0b0594d62dff3","author":{"email":"chongtongTech@users.noreply.github.com","name":"chongtongTech"},"message":"Profile automatically generated by GitHub Actions","distinct":true,"url":"https://api.github.com/repos/chongtongTech/chongtongTech/commits/ef3e7269ab415664878111fba6a0b0594d62dff3"}]},"public":true,"created_at":"2024-12-16T18:33:35Z"},{"id":"44838896203","type":"CreateEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":52010989,"name":"libmtp/libmtp","url":"https://api.github.com/repos/libmtp/libmtp"},"payload":{"ref":"dependabot/github_actions/github/codeql-action-3.27.9","ref_type":"branch","master_branch":"master","description":"A library to access MTP (Media Transfer Protocol) Devices.","pusher_type":"user"},"public":true,"created_at":"2024-12-16T18:33:35Z","org":{"id":17316625,"login":"libmtp","gravatar_id":"","url":"https://api.github.com/orgs/libmtp","avatar_url":"https://avatars.githubusercontent.com/u/17316625?"}},{"id":"44838896209","type":"DeleteEvent","actor":{"id":1010226,"login":"thibaultmol","display_login":"thibaultmol","gravatar_id":"","url":"https://api.github.com/users/thibaultmol","avatar_url":"https://avatars.githubusercontent.com/u/1010226?"},"repo":{"id":776425727,"name":"thibaultmol/kagi-docs","url":"https://api.github.com/repos/thibaultmol/kagi-docs"},"payload":{"ref":"Translate-1","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2024-12-16T18:33:35Z"},{"id":"44838896198","type":"WatchEvent","actor":{"id":153089862,"login":"vitalyzhuks","display_login":"vitalyzhuks","gravatar_id":"","url":"https://api.github.com/users/vitalyzhuks","avatar_url":"https://avatars.githubusercontent.com/u/153089862?"},"repo":{"id":622472032,"name":"R1M-NODES/explorer","url":"https://api.github.com/repos/R1M-NODES/explorer"},"payload":{"action":"started"},"public":true,"created_at":"2024-12-16T18:33:35Z","org":{"id":112927231,"login":"R1M-NODES","gravatar_id":"","url":"https://api.github.com/orgs/R1M-NODES","avatar_url":"https://avatars.githubusercontent.com/u/112927231?"}},{"id":"44838896196","type":"IssueCommentEvent","actor":{"id":75433959,"login":"openshift-ci[bot]","display_login":"openshift-ci","gravatar_id":"","url":"https://api.github.com/users/openshift-ci[bot]","avatar_url":"https://avatars.githubusercontent.com/u/75433959?"},"repo":{"id":715942193,"name":"openshift/lightspeed-service","url":"https://api.github.com/repos/openshift/lightspeed-service"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/openshift/lightspeed-service/issues/2008","repository_url":"https://api.github.com/repos/openshift/lightspeed-service","labels_url ...

# %%
r.json()
# Out:
# [{'id': '44838896223',
#   'type': 'CreateEvent',
#   'actor': {'id': 103665518,
#    'login': 'Barreratomas',
#    'display_login': 'Barreratomas',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Barreratomas',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103665518?'},
#   'repo': {'id': 904361852,
#    'name': 'Barreratomas/horarios',
#    'url': 'https://api.github.com/repos/Barreratomas/horarios'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896179',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 898201892,
#    'name': 'chongtongTech/chongtongTech',
#    'url': 'https://api.github.com/repos/chongtongTech/chongtongTech'},
#   'payload': {'repository_id': 898201892,
#    'push_id': 21735153894,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ef3e7269ab415664878111fba6a0b0594d62dff3',
#    'before': 'ba9b0981e57f3c7b0ee0f2803aa10505cb4792b7',
#    'commits': [{'sha': 'ef3e7269ab415664878111fba6a0b0594d62dff3',
#      'author': {'email': 'chongtongTech@users.noreply.github.com',
#       'name': 'chongtongTech'},
#      'message': 'Profile automatically generated by GitHub Actions',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chongtongTech/chongtongTech/commits/ef3e7269ab415664878111fba6a0b0594d62dff3'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896203',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 52010989,
#    'name': 'libmtp/libmtp',
#    'url': 'https://api.github.com/repos/libmtp/libmtp'},
#   'payload': {'ref': 'dependabot/github_actions/github/codeql-action-3.27.9',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A library to access MTP (Media Transfer Protocol) Devices.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z',
#   'org': {'id': 17316625,
#    'login': 'libmtp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/libmtp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17316625?'}},
#  {'id': '44838896209',
#   'type': 'DeleteEvent',
#   'actor': {'id': 1010226,
#    'login': 'thibaultmol',
#    'display_login': 'thibaultmol',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thibaultmol',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1010226?'},
#   'repo': {'id': 776425727,
#    'name': 'thibaultmol/kagi-docs',
#    'url': 'https://api.github.com/repos/thibaultmol/kagi-docs'},
#   'payload': {'ref': 'Translate-1',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896198',
#   'type': 'WatchEvent',
#   'actor': {'id': 153089862,
#    'login': 'vitalyzhuks',
#    'display_login': 'vitalyzhuks',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vitalyzhuks',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/153089862?'},
#   'repo': {'id': 622472032,
#    'name': 'R1M-NODES/explorer',
#    'url': 'https://api.github.com/repos/R1M-NODES/explorer'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z',
#   'org': {'id': 112927231,
#    'login': 'R1M-NODES',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/R1M-NODES',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112927231?'}},
#  {'id': '44838896196',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 75433959,
#    'login': 'openshift-ci[bot]',
#    'display_login': 'openshift-ci',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/openshift-ci[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75433959?'},
#   'repo': {'id': 715942193,
#    'name': 'openshift/lightspeed-service',
#    'url': 'https://api.github.com/repos/openshift/lightspeed-service'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/2008',
#     'repository_url': 'https://api.github.com/repos/openshift/lightspeed-service',
#     'labels_url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/2008/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/2008/comments',
#     'events_url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/2008/events',
#     'html_url': 'https://github.com/openshift/lightspeed-service/pull/2008',
#     'id': 2717716451,
#     'node_id': 'PR_kwDOKqxpMc6ECc_3',
#     'number': 2008,
#     'title': 'OLS-587 - Adding test_generated_service_certs_rotation',
#     'user': {'login': 'JoaoFula',
#      'id': 26280574,
#      'node_id': 'MDQ6VXNlcjI2MjgwNTc0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/26280574?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/JoaoFula',
#      'html_url': 'https://github.com/JoaoFula',
#      'followers_url': 'https://api.github.com/users/JoaoFula/followers',
#      'following_url': 'https://api.github.com/users/JoaoFula/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/JoaoFula/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/JoaoFula/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/JoaoFula/subscriptions',
#      'organizations_url': 'https://api.github.com/users/JoaoFula/orgs',
#      'repos_url': 'https://api.github.com/users/JoaoFula/repos',
#      'events_url': 'https://api.github.com/users/JoaoFula/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/JoaoFula/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 4,
#     'created_at': '2024-12-04T13:18:52Z',
#     'updated_at': '2024-12-16T18:33:35Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/openshift/lightspeed-service/pulls/2008',
#      'html_url': 'https://github.com/openshift/lightspeed-service/pull/2008',
#      'diff_url': 'https://github.com/openshift/lightspeed-service/pull/2008.diff',
#      'patch_url': 'https://github.com/openshift/lightspeed-service/pull/2008.patch',
#      'merged_at': None},
#     'body': '## Description\r\n\r\n<!--- Describe your changes in detail -->\r\n\r\n## Type of change\r\n\r\n- [x] New test\r\n\r\n## Related Tickets & Documents\r\n\r\n- Related Issue #\r\n- Closes #\r\n\r\n## Checklist before requesting a review\r\n\r\n- [ ] I have performed a self-review of my code.\r\n- [ ] PR has passed all pre-merge test jobs.\r\n- [ ] If it is a core feature, I have added thorough tests.\r\n\r\n## Testing\r\n- Please provide detailed steps to perform tests related to this code change.\r\n- How were the fix/results from this change verified? Please provide relevant screenshots or results.\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/2008/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/2008/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/comments/2546357446',
#     'html_url': 'https://github.com/openshift/lightspeed-service/pull/2008#issuecomment-2546357446',
#     'issue_url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/2008',
#     'id': 2546357446,
#     'node_id': 'IC_kwDOKqxpMc6XxlTG',
#     'user': {'login': 'openshift-ci[bot]',
#      'id': 75433959,
#      'node_id': 'MDM6Qm90NzU0MzM5NTk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/91280?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/openshift-ci%5Bbot%5D',
#      'html_url': 'https://github.com/apps/openshift-ci',
#      'followers_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2024-12-16T18:33:34Z',
#     'updated_at': '2024-12-16T18:33:34Z',
#     'author_association': 'NONE',
#     'body': '@JoaoFula: The following test **failed**, say `/retest` to rerun all failed tests or `/retest-required` to rerun all mandatory failed tests:\n\nTest name | Commit | Details | Required | Rerun command\n--- | --- | --- | --- | ---\nci/prow/4.17-e2e-ols-cluster | 96720d8909be6c717670bd77f9f0cf44d5263da1 | [link](https://prow.ci.openshift.org/view/gs/test-platform-results/pr-logs/pull/openshift_lightspeed-service/2008/pull-ci-openshift-lightspeed-service-main-4.17-e2e-ols-cluster/1868659342182453248) | true | `/test 4.17-e2e-ols-cluster`\n\n[Full PR test history](https://prow.ci.openshift.org/pr-history?org=openshift&repo=lightspeed-service&pr=2008). [Your PR dashboard](https://prow.ci.openshift.org/pr?query=is:pr+state:open+author:JoaoFula).\n\n<details>\n\nInstructions for interacting with me using PR comments are available [here](https://git.k8s.io/community/contributors/guide/pull-requests.md).  If you have questions or suggestions related to my behavior, please file an issue against the [kubernetes-sigs/prow](https://github.com/kubernetes-sigs/prow/issues/new?title=Prow%20issue:) repository. I understand the commands that are listed [here](https://go.k8s.io/bot-commands).\n</details>\n<!-- test report -->',
#     'reactions': {'url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/comments/2546357446/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': {'id': 91280,
#      'client_id': 'Iv1.09d5e15025fbddc8',
#      'slug': 'openshift-ci',
#      'node_id': 'MDM6QXBwOTEyODA=',
#      'owner': {'login': 'openshift',
#       'id': 792337,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5MjMzNw==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/792337?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/openshift',
#       'html_url': 'https://github.com/openshift',
#       'followers_url': 'https://api.github.com/users/openshift/followers',
#       'following_url': 'https://api.github.com/users/openshift/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/openshift/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/openshift/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/openshift/subscriptions',
#       'organizations_url': 'https://api.github.com/users/openshift/orgs',
#       'repos_url': 'https://api.github.com/users/openshift/repos',
#       'events_url': 'https://api.github.com/users/openshift/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/openshift/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'name': 'OpenShift CI',
#      'description': 'The OpenShift CI system integrates with GitHub to provide pull request authors with a performant and scalable solution to testing their code, whether it be part of the OpenShift Container Platform or an application layered on top.',
#      'external_url': 'https://www.openshift.com/',
#      'html_url': 'https://github.com/apps/openshift-ci',
#      'created_at': '2020-12-03T14:13:46Z',
#      'updated_at': '2024-12-13T19:34:58Z',
#      'permissions': {'actions': 'write',
#       'administration': 'write',
#       'checks': 'write',
#       'contents': 'write',
#       'deployments': 'write',
#       'issues': 'write',
#       'members': 'write',
#       'metadata': 'read',
#       'organization_administration': 'write',
#       'organization_hooks': 'write',
#       'organization_plan': 'read',
#       'organization_projects': 'admin',
#       'organization_secrets': 'write',
#       'organization_self_hosted_runners': 'write',
#       'organization_user_blocking': 'write',
#       'packages': 'write',
#       'pages': 'write',
#       'pull_requests': 'write',
#       'repository_hooks': 'write',
#       'repository_projects': 'admin',
#       'secrets': 'write',
#       'security_events': 'write',
#       'statuses': 'write',
#       'team_discussions': 'write',
#       'vulnerability_alerts': 'read',
#       'workflows': 'write'},
#      'events': ['check_run',
#       'check_suite',
#       'code_scanning_alert',
#       'commit_comment',
#       'create',
#       'delete',
#       'deployment',
#       'deployment_status',
#       'deploy_key',
#       'fork',
#       'issues',
#       'issue_comment',
#       'label',
#       'member',
#       'pull_request',
#       'pull_request_review',
#       'pull_request_review_comment',
#       'push',
#       'release',
#       'status']}}},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z',
#   'org': {'id': 792337,
#    'login': 'openshift',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openshift',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/792337?'}},
#  {'id': '44838896197',
#   'type': 'WatchEvent',
#   'actor': {'id': 102030673,
#    'login': 'Paulo1402',
#    'display_login': 'Paulo1402',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Paulo1402',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/102030673?'},
#   'repo': {'id': 671000997,
#    'name': 'jiisanda/docflow',
#    'url': 'https://api.github.com/repos/jiisanda/docflow'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896190',
#   'type': 'PushEvent',
#   'actor': {'id': 85067742,
#    'login': 'dwi8',
#    'display_login': 'dwi8',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dwi8',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/85067742?'},
#   'repo': {'id': 904338519,
#    'name': 'dwi8/NeuralForge',
#    'url': 'https://api.github.com/repos/dwi8/NeuralForge'},
#   'payload': {'repository_id': 904338519,
#    'push_id': 21735153830,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e3aa2353d7dbec154357534a1ddb01d0caadf333',
#    'before': '64f4ea24ffec78b156b486259deaeeabb4152d5b',
#    'commits': [{'sha': 'e3aa2353d7dbec154357534a1ddb01d0caadf333',
#      'author': {'email': 'mhdsfntfbb@rambler.ru', 'name': 'dwi8'},
#      'message': '',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dwi8/NeuralForge/commits/e3aa2353d7dbec154357534a1ddb01d0caadf333'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896192',
#   'type': 'WatchEvent',
#   'actor': {'id': 188355797,
#    'login': 'victor-ironwillvio',
#    'display_login': 'victor-ironwillvio',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/victor-ironwillvio',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/188355797?'},
#   'repo': {'id': 904270698,
#    'name': 'tuqagigusiqa/roblox-script',
#    'url': 'https://api.github.com/repos/tuqagigusiqa/roblox-script'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896187',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 515042508,
#    'name': 'Kir93/next-page-zustand-reactQuery-template',
#    'url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template'},
#   'payload': {'action': 'opened',
#    'number': 435,
#    'pull_request': {'url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/pulls/435',
#     'id': 2238004323,
#     'node_id': 'PR_kwDOHrLszM6FZTxj',
#     'html_url': 'https://github.com/Kir93/next-page-zustand-reactQuery-template/pull/435',
#     'diff_url': 'https://github.com/Kir93/next-page-zustand-reactQuery-template/pull/435.diff',
#     'patch_url': 'https://github.com/Kir93/next-page-zustand-reactQuery-template/pull/435.patch',
#     'issue_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/issues/435',
#     'number': 435,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump @emotion/styled from 11.13.0 to 11.14.0',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'Bumps [@emotion/styled](https://github.com/emotion-js/emotion) from 11.13.0 to 11.14.0.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/emotion-js/emotion/releases"><code>@\u200bemotion/styled</code>\'s releases</a>.</em></p>\n<blockquote>\n<h2><code>@\u200bemotion/styled</code><a href="https://github.com/11"><code>@\u200b11</code></a>.14.0</h2>\n<h3>Minor Changes</h3>\n<ul>\n<li><a href="https://redirect.github.com/emotion-js/emotion/pull/3284">#3284</a> <a href="https://github.com/emotion-js/emotion/commit/a19d019bd418ebc3b9cba0e58f58b36ac2862a42"><code>a19d019</code></a> Thanks <a href="https://github.com/Andarist"><code>@\u200bAndarist</code></a>! - Source code has been migrated to TypeScript. From now on type declarations will be emitted based on that, instead of being hand-written.</li>\n</ul>\n<h3>Patch Changes</h3>\n<ul>\n<li>Updated dependencies [<a href="https://github.com/emotion-js/emotion/commit/e1bf17ee87ec51da1412eb5291460ea95a39d27a"><code>e1bf17e</code></a>]:\n<ul>\n<li><code>@\u200bemotion/use-insertion-effect-with-fallbacks</code><a href="https://github.com/1"><code>@\u200b1</code></a>.2.0</li>\n</ul>\n</li>\n</ul>\n<h2><code>@\u200bemotion/styled</code><a href="https://github.com/11"><code>@\u200b11</code></a>.13.5</h2>\n<h3>Patch Changes</h3>\n<ul>\n<li>\n<p><a href="https://redirect.github.com/emotion-js/emotion/pull/3270">#3270</a> <a href="https://github.com/emotion-js/emotion/commit/77d930dc708015ff6fd34a1084bb343b02d732fa"><code>77d930d</code></a> Thanks <a href="https://github.com/emmatown"><code>@\u200bemmatown</code></a>! - Fix inconsistent hashes using development vs production bundles/<code>exports</code> conditions when using <code>@emotion/babel-plugin</code> with <code>sourceMap: true</code> (the default). This is particularly visible when using Emotion with the Next.js Pages router where the <code>development</code> condition is used when bundling code but not when importing external code with Node.js.</p>\n</li>\n<li>\n<p>Updated dependencies [<a href="https://github.com/emotion-js/emotion/commit/77d930dc708015ff6fd34a1084bb343b02d732fa"><code>77d930d</code></a>]:</p>\n<ul>\n<li><code>@\u200bemotion/serialize</code><a href="https://github.com/1"><code>@\u200b1</code></a>.3.3</li>\n<li><code>@\u200bemotion/utils</code><a href="https://github.com/1"><code>@\u200b1</code></a>.4.2</li>\n<li><code>@\u200bemotion/babel-plugin</code><a href="https://github.com/11"><code>@\u200b11</code></a>.13.5</li>\n</ul>\n</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/emotion-js/emotion/commit/3c19ce5997f73960679e546af47801205631dfde"><code>3c19ce5</code></a> Version Packages (<a href="https://redirect.github.com/emotion-js/emotion/issues/3280">#3280</a>)</li>\n<li><a href="https://github.com/emotion-js/emotion/commit/a19d019bd418ebc3b9cba0e58f58b36ac2862a42"><code>a19d019</code></a> Convert <code>@emotion/styled</code>\'s source code to TypeScript (<a href="https://redirect.github.com/emotion-js/emotion/issues/3284">#3284</a>)</li>\n<li><a href="https://github.com/emotion-js/emotion/commit/5974e33fcb5e7aee177408684ac6fe8b38b3e353"><code>5974e33</code></a> Fix JSX namespace <a href="https://github.com/ts-ignores"><code>@\u200bts-ignores</code></a> (<a href="https://redirect.github.com/emotion-js/emotion/issues/3282">#3282</a>)</li>\n<li><a href="https://github.com/emotion-js/emotion/commit/fc4d7bd744c205f55513dcd4e4e5134198c219de"><code>fc4d7bd</code></a> Convert <code>@emotion/react</code>\'s source code to TypeScript (<a href="https://redirect.github.com/emotion-js/emotion/issues/3281">#3281</a>)</li>\n<li><a href="https://github.com/emotion-js/emotion/commit/8dc1a6dd19d2dc9ce435ef0aff85ccf5647f5d2e"><code>8dc1a6d</code></a> Convert <code>@emotion/cache</code>\'s source code to TypeScript (<a href="https://redirect.github.com/emotion-js/emotion/issues/3277">#3277</a>)</li>\n<li><a h ...
#     'created_at': '2024-12-16T18:33:33Z',
#     'updated_at': '2024-12-16T18:33:34Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '019ef2bec64469e079e802de2fa7e047fe817c1c',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 5494401298,
#       'node_id': 'LA_kwDOHrLszM8AAAABR33pEg',
#       'url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/pulls/435/commits',
#     'review_comments_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/pulls/435/comments',
#     'review_comment_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/issues/435/comments',
#     'statuses_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/statuses/043f460848abe035e5dcc296fb98f45553900051',
#     'head': {'label': 'Kir93:dependabot/npm_and_yarn/emotion/styled-11.14.0',
#      'ref': 'dependabot/npm_and_yarn/emotion/styled-11.14.0',
#      'sha': '043f460848abe035e5dcc296fb98f45553900051',
#      'user': {'login': 'Kir93',
#       'id': 66928798,
#       'node_id': 'MDQ6VXNlcjY2OTI4Nzk4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/66928798?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Kir93',
#       'html_url': 'https://github.com/Kir93',
#       'followers_url': 'https://api.github.com/users/Kir93/followers',
#       'following_url': 'https://api.github.com/users/Kir93/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Kir93/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Kir93/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Kir93/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Kir93/orgs',
#       'repos_url': 'https://api.github.com/users/Kir93/repos',
#       'events_url': 'https://api.github.com/users/Kir93/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Kir93/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 515042508,
#       'node_id': 'R_kgDOHrLszA',
#       'name': 'next-page-zustand-reactQuery-template',
#       'full_name': 'Kir93/next-page-zustand-reactQuery-template',
#       'private': False,
#       'owner': {'login': 'Kir93',
#        'id': 66928798,
#        'node_id': 'MDQ6VXNlcjY2OTI4Nzk4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/66928798?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Kir93',
#        'html_url': 'https://github.com/Kir93',
#        'followers_url': 'https://api.github.com/users/Kir93/followers',
#        'following_url': 'https://api.github.com/users/Kir93/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Kir93/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Kir93/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Kir93/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Kir93/orgs',
#        'repos_url': 'https://api.github.com/users/Kir93/repos',
#        'events_url': 'https://api.github.com/users/Kir93/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Kir93/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/Kir93/next-page-zustand-reactQuery-template',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template',
#       'forks_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/forks',
#       'keys_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/teams',
#       'hooks_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/events',
#       'assignees_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/tags',
#       'blobs_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/languages',
#       'stargazers_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/subscription',
#       'commits_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/merges',
#       'archive_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/downloads',
#       'issues_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/deployments',
#       'created_at': '2022-07-18T05:09:53Z',
#       'updated_at': '2024-12-12T05:21:43Z',
#       'pushed_at': '2024-12-16T18:33:32Z',
#       'git_url': 'git://github.com/Kir93/next-page-zustand-reactQuery-template.git',
#       'ssh_url': 'git@github.com:Kir93/next-page-zustand-reactQuery-template.git',
#       'clone_url': 'https://github.com/Kir93/next-page-zustand-reactQuery-template.git',
#       'svn_url': 'https://github.com/Kir93/next-page-zustand-reactQuery-template',
#       'homepage': None,
#       'size': 3106,
#       'stargazers_count': 6,
#       'watchers_count': 6,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': True,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 2,
#       'watchers': 6,
#       'default_branch': 'main'}},
#     'base': {'label': 'Kir93:main',
#      'ref': 'main',
#      'sha': '3a8cf7ed3d77dafdfa212461ee870fc41478d183',
#      'user': {'login': 'Kir93',
#       'id': 66928798,
#       'node_id': 'MDQ6VXNlcjY2OTI4Nzk4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/66928798?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Kir93',
#       'html_url': 'https://github.com/Kir93',
#       'followers_url': 'https://api.github.com/users/Kir93/followers',
#       'following_url': 'https://api.github.com/users/Kir93/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Kir93/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Kir93/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Kir93/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Kir93/orgs',
#       'repos_url': 'https://api.github.com/users/Kir93/repos',
#       'events_url': 'https://api.github.com/users/Kir93/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Kir93/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 515042508,
#       'node_id': 'R_kgDOHrLszA',
#       'name': 'next-page-zustand-reactQuery-template',
#       'full_name': 'Kir93/next-page-zustand-reactQuery-template',
#       'private': False,
#       'owner': {'login': 'Kir93',
#        'id': 66928798,
#        'node_id': 'MDQ6VXNlcjY2OTI4Nzk4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/66928798?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Kir93',
#        'html_url': 'https://github.com/Kir93',
#        'followers_url': 'https://api.github.com/users/Kir93/followers',
#        'following_url': 'https://api.github.com/users/Kir93/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Kir93/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Kir93/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Kir93/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Kir93/orgs',
#        'repos_url': 'https://api.github.com/users/Kir93/repos',
#        'events_url': 'https://api.github.com/users/Kir93/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Kir93/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/Kir93/next-page-zustand-reactQuery-template',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template',
#       'forks_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/forks',
#       'keys_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/teams',
#       'hooks_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/events',
#       'assignees_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/tags',
#       'blobs_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/languages',
#       'stargazers_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/subscription',
#       'commits_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/merges',
#       'archive_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/downloads',
#       'issues_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/deployments',
#       'created_at': '2022-07-18T05:09:53Z',
#       'updated_at': '2024-12-12T05:21:43Z',
#       'pushed_at': '2024-12-16T18:33:32Z',
#       'git_url': 'git://github.com/Kir93/next-page-zustand-reactQuery-template.git',
#       'ssh_url': 'git@github.com:Kir93/next-page-zustand-reactQuery-template.git',
#       'clone_url': 'https://github.com/Kir93/next-page-zustand-reactQuery-template.git',
#       'svn_url': 'https://github.com/Kir93/next-page-zustand-reactQuery-template',
#       'homepage': None,
#       'size': 3106,
#       'stargazers_count': 6,
#       'watchers_count': 6,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': True,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 2,
#       'watchers': 6,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/pulls/435'},
#      'html': {'href': 'https://github.com/Kir93/next-page-zustand-reactQuery-template/pull/435'},
#      'issue': {'href': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/issues/435'},
#      'comments': {'href': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/issues/435/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/pulls/435/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/pulls/435/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Kir93/next-page-zustand-reactQuery-template/statuses/043f460848abe035e5dcc296fb98f45553900051'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 12,
#     'deletions': 12,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896163',
#   'type': 'PushEvent',
#   'actor': {'id': 81137680,
#    'login': 'harrybaals72',
#    'display_login': 'harrybaals72',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/harrybaals72',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81137680?'},
#   'repo': {'id': 886967007,
#    'name': 'harrybaals72/CMR-S',
#    'url': 'https://api.github.com/repos/harrybaals72/CMR-S'},
#   'payload': {'repository_id': 886967007,
#    'push_id': 21735153929,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '27aadf8c3666fca5ace4d7e495832376b982f312',
#    'before': 'f02ef8890d00c93dc98274846cfaf6920714df54',
#    'commits': [{'sha': '27aadf8c3666fca5ace4d7e495832376b982f312',
#      'author': {'email': 'nkosa427@gmail.com', 'name': 'nkosa427'},
#      'message': '3s',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/harrybaals72/CMR-S/commits/27aadf8c3666fca5ace4d7e495832376b982f312'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896151',
#   'type': 'PushEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 162789247,
#    'name': 'inabagumi/animare-shindan',
#    'url': 'https://api.github.com/repos/inabagumi/animare-shindan'},
#   'payload': {'repository_id': 162789247,
#    'push_id': 21735153835,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/renovate/major-8-typescript-eslint-monorepo',
#    'head': '587577e632045565c716de00e6ef4f5f2d4ee91a',
#    'before': '67834bd4533f534a0a7fb0a8e193930f716b565d',
#    'commits': [{'sha': '587577e632045565c716de00e6ef4f5f2d4ee91a',
#      'author': {'email': '29139614+renovate[bot]@users.noreply.github.com',
#       'name': 'renovate[bot]'},
#      'message': 'build(deps): update typescript-eslint monorepo to v8',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/inabagumi/animare-shindan/commits/587577e632045565c716de00e6ef4f5f2d4ee91a'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z',
#   'org': {'id': 42648621,
#    'login': 'inabagumi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/inabagumi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42648621?'}},
#  {'id': '44838896165',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 533066791,
#    'name': 'Gabrielmong/Gabrielmong',
#    'url': 'https://api.github.com/repos/Gabrielmong/Gabrielmong'},
#   'payload': {'repository_id': 533066791,
#    'push_id': 21735153896,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '35760410e05dd275fb1e01207f1d4362f4db8d96',
#    'before': 'b0b1e7af1da9743379694a504189ce3c17a8a62a',
#    'commits': [{'sha': '35760410e05dd275fb1e01207f1d4362f4db8d96',
#      'author': {'email': 'github-actions@github.com',
#       'name': 'github-actions'},
#      'message': 'generated',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gabrielmong/Gabrielmong/commits/35760410e05dd275fb1e01207f1d4362f4db8d96'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896168',
#   'type': 'PushEvent',
#   'actor': {'id': 7020903,
#    'login': 'lmerynda',
#    'display_login': 'lmerynda',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lmerynda',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7020903?'},
#   'repo': {'id': 672162116,
#    'name': 'lmerynda/KnightsOfDarkness',
#    'url': 'https://api.github.com/repos/lmerynda/KnightsOfDarkness'},
#   'payload': {'repository_id': 672162116,
#    'push_id': 21735153982,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e074541a8f12d223082baaa93ed10350c3ecacff',
#    'before': 'b9e13b39144824b844e990e312fd56b706155103',
#    'commits': [{'sha': 'e074541a8f12d223082baaa93ed10350c3ecacff',
#      'author': {'email': 'lmerynda@gmail.com', 'name': 'lmerynda'},
#      'message': 'fix tests for units',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lmerynda/KnightsOfDarkness/commits/e074541a8f12d223082baaa93ed10350c3ecacff'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896159',
#   'type': 'PushEvent',
#   'actor': {'id': 102790989,
#    'login': 'kpnsec',
#    'display_login': 'kpnsec',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kpnsec',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/102790989?'},
#   'repo': {'id': 713192428,
#    'name': 'kpnsec/iplist',
#    'url': 'https://api.github.com/repos/kpnsec/iplist'},
#   'payload': {'repository_id': 713192428,
#    'push_id': 21735153964,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0981904b73ca77a14bc91d5e256248cb1b479637',
#    'before': '921832399c3fddd03b629bf87c0ca8b227c1642f',
#    'commits': [{'sha': '0981904b73ca77a14bc91d5e256248cb1b479637',
#      'author': {'email': '102790989+kpnsec@users.noreply.github.com',
#       'name': 'kpnsec'},
#      'message': 'a new commit message',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kpnsec/iplist/commits/0981904b73ca77a14bc91d5e256248cb1b479637'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896152',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 793669954,
#    'name': 'ethanuppal/ethanuppal',
#    'url': 'https://api.github.com/repos/ethanuppal/ethanuppal'},
#   'payload': {'repository_id': 793669954,
#    'push_id': 21735153901,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/contr-graph-gif',
#    'head': 'dc467276786458874a96613e3e764cb2be82350d',
#    'before': '305886daa40db16144f77e5883d357f920556308',
#    'commits': [{'sha': 'dc467276786458874a96613e3e764cb2be82350d',
#      'author': {'email': '113849268+ethanuppal@users.noreply.github.com',
#       'name': 'Ethan Uppal'},
#      'message': 'Generated 3D Contribution Graph GIF',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ethanuppal/ethanuppal/commits/dc467276786458874a96613e3e764cb2be82350d'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896156',
#   'type': 'CreateEvent',
#   'actor': {'id': 162827622,
#    'login': 'yulti879',
#    'display_login': 'yulti879',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yulti879',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/162827622?'},
#   'repo': {'id': 904360553,
#    'name': 'yulti879/team',
#    'url': 'https://api.github.com/repos/yulti879/team'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896117',
#   'type': 'WatchEvent',
#   'actor': {'id': 14543143,
#    'login': 'mvandermeulen',
#    'display_login': 'mvandermeulen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mvandermeulen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14543143?'},
#   'repo': {'id': 380478661,
#    'name': 'jakbin/py-localtunnel',
#    'url': 'https://api.github.com/repos/jakbin/py-localtunnel'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896119',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 867623432,
#    'name': 'xrwt/degisiklik-yapan-sistem',
#    'url': 'https://api.github.com/repos/xrwt/degisiklik-yapan-sistem'},
#   'payload': {'repository_id': 867623432,
#    'push_id': 21735153996,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': 'aa976e6fe30181c6db2c48e486ffaa7093982d17',
#    'before': '3908b7be67f6545eb3ecd98270279cfb6552b7cd',
#    'commits': [{'sha': '32983c1b7815d908ba722f9c874923e23560cd6d',
#      'author': {'email': 'xrqu.live@gmail.com', 'name': 'xrwt'},
#      'message': '[➕] Güncelleme (2. Ekleme, 2168. Değişiklik)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xrwt/degisiklik-yapan-sistem/commits/32983c1b7815d908ba722f9c874923e23560cd6d'},
#     {'sha': 'aa976e6fe30181c6db2c48e486ffaa7093982d17',
#      'author': {'email': 'xrqu.live@gmail.com', 'name': 'xrwt'},
#      'message': '[➖] Güncelleme (2. Çıkarma, 2168. Değişiklik)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xrwt/degisiklik-yapan-sistem/commits/aa976e6fe30181c6db2c48e486ffaa7093982d17'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896102',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 812859341,
#    'name': 'diotoborg/soluta-cupiditate-nobis',
#    'url': 'https://api.github.com/repos/diotoborg/soluta-cupiditate-nobis'},
#   'payload': {'repository_id': 812859341,
#    'push_id': 21735154026,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '43eb5861760b8e433f262f5a8e524ab808aef507',
#    'before': '955bd5634667185e683fb698fa8a1e93c2ce29f2',
#    'commits': [{'sha': '43eb5861760b8e433f262f5a8e524ab808aef507',
#      'author': {'email': 'diotobenijj@users.noreply.github.com',
#       'name': 'diotobenijj'},
#      'message': 'Wefes kodohitamo lob watex mumelo lubapacupi code kakadale feature code.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/diotoborg/soluta-cupiditate-nobis/commits/43eb5861760b8e433f262f5a8e524ab808aef507'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z',
#   'org': {'id': 167953019,
#    'login': 'diotoborg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/diotoborg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/167953019?'}},
#  {'id': '44838896097',
#   'type': 'PushEvent',
#   'actor': {'id': 22035469,
#    'login': 'sayaz',
#    'display_login': 'sayaz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sayaz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22035469?'},
#   'repo': {'id': 904358029,
#    'name': 'sayaz/powder_byod',
#    'url': 'https://api.github.com/repos/sayaz/powder_byod'},
#   'payload': {'repository_id': 904358029,
#    'push_id': 21735153873,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1f79b2a548efaf0611ee6f03d53774e357f71071',
#    'before': '31f840e1358d58641f9b7095bb2ec381f50fb50d',
#    'commits': [{'sha': '1f79b2a548efaf0611ee6f03d53774e357f71071',
#      'author': {'email': 'sayazmahmud@gmail.com', 'name': 'Syed Ayaz Mahmud'},
#      'message': 'Update profile.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sayaz/powder_byod/commits/1f79b2a548efaf0611ee6f03d53774e357f71071'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896080',
#   'type': 'PushEvent',
#   'actor': {'id': 166895733,
#    'login': 'swa-runner-app[bot]',
#    'display_login': 'swa-runner-app',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/swa-runner-app[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166895733?'},
#   'repo': {'id': 904361466,
#    'name': 'static-web-apps-testing-org/swafb41275f414045f290b815539632fd57',
#    'url': 'https://api.github.com/repos/static-web-apps-testing-org/swafb41275f414045f290b815539632fd57'},
#   'payload': {'repository_id': 904361466,
#    'push_id': 21735153834,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0a31ec340eaea2356d6da5c571fec9f95c344e37',
#    'before': '37494f953ad5b846f0ac37980d06f6ca10144300',
#    'commits': [{'sha': '0a31ec340eaea2356d6da5c571fec9f95c344e37',
#      'author': {'email': '166895733+swa-runner-app[bot]@users.noreply.github.com',
#       'name': 'swa-runner-app[bot]'},
#      'message': 'Writing file Client/wwwroot/icon-192.png',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/static-web-apps-testing-org/swafb41275f414045f290b815539632fd57/commits/0a31ec340eaea2356d6da5c571fec9f95c344e37'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z',
#   'org': {'id': 96167003,
#    'login': 'static-web-apps-testing-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/static-web-apps-testing-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96167003?'}},
#  {'id': '44838896098',
#   'type': 'PushEvent',
#   'actor': {'id': 21973124,
#    'login': 'bilallgunaydin',
#    'display_login': 'bilallgunaydin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bilallgunaydin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21973124?'},
#   'repo': {'id': 904343951,
#    'name': 'bilallgunaydin/GoWitCaseStudy',
#    'url': 'https://api.github.com/repos/bilallgunaydin/GoWitCaseStudy'},
#   'payload': {'repository_id': 904343951,
#    'push_id': 21735153811,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bf27d64af03b81ed66e11dd068b92593e17b7077',
#    'before': '43a79a6abc925996b5cfd6245b0de30b7239caff',
#    'commits': [{'sha': 'bf27d64af03b81ed66e11dd068b92593e17b7077',
#      'author': {'email': 'bilallgunaydin@gmail.com', 'name': 'Bilal Günaydın'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bilallgunaydin/GoWitCaseStudy/commits/bf27d64af03b81ed66e11dd068b92593e17b7077'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896087',
#   'type': 'CreateEvent',
#   'actor': {'id': 58259069,
#    'login': 'bambootest-bot',
#    'display_login': 'bambootest-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bambootest-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58259069?'},
#   'repo': {'id': 904361667,
#    'name': 'bambootest-bot-organization/githubtest-testfork-Rbxzw',
#    'url': 'https://api.github.com/repos/bambootest-bot-organization/githubtest-testfork-Rbxzw'},
#   'payload': {'ref': 'pr-branch73359145',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z',
#   'org': {'id': 110661736,
#    'login': 'bambootest-bot-organization',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/bambootest-bot-organization',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/110661736?'}},
#  {'id': '44838896076',
#   'type': 'PushEvent',
#   'actor': {'id': 13325366,
#    'login': 'jhonhoga',
#    'display_login': 'jhonhoga',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jhonhoga',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13325366?'},
#   'repo': {'id': 904299737,
#    'name': 'jhonhoga/chatbot-expedientes',
#    'url': 'https://api.github.com/repos/jhonhoga/chatbot-expedientes'},
#   'payload': {'repository_id': 904299737,
#    'push_id': 21735153999,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '51debf22615ae6b424056c3fe99783080e6b7095',
#    'before': '44f6c8800d2efab5c189323bbdbfa5f135b88cb0',
#    'commits': [{'sha': '51debf22615ae6b424056c3fe99783080e6b7095',
#      'author': {'email': 'jhondcali@hotmail.com', 'name': 'jhonhoga'},
#      'message': 'Fix: correccion y alineacion con koyeb json',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jhonhoga/chatbot-expedientes/commits/51debf22615ae6b424056c3fe99783080e6b7095'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896058',
#   'type': 'PushEvent',
#   'actor': {'id': 183426947,
#    'login': 'emluminee',
#    'display_login': 'emluminee',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/emluminee',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/183426947?'},
#   'repo': {'id': 872250942,
#    'name': 'emluminee/emluminee.github.io',
#    'url': 'https://api.github.com/repos/emluminee/emluminee.github.io'},
#   'payload': {'repository_id': 872250942,
#    'push_id': 21735153863,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cca550c172fcf32d54d264990e2053f59e7b7161',
#    'before': '29960439e21a389f1be60797ad73258fee206c03',
#    'commits': [{'sha': 'cca550c172fcf32d54d264990e2053f59e7b7161',
#      'author': {'email': 'emluminee.art@gmail.com', 'name': 'emluminee'},
#      'message': 'create website',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/emluminee/emluminee.github.io/commits/cca550c172fcf32d54d264990e2053f59e7b7161'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896070',
#   'type': 'DeleteEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 756436459,
#    'name': 'larryh0717/go-proxy-bingai',
#    'url': 'https://api.github.com/repos/larryh0717/go-proxy-bingai'},
#   'payload': {'ref': 'nightly', 'ref_type': 'tag', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896050',
#   'type': 'DeleteEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 543918342,
#    'name': 'JoshuaKGoldberg/create-typescript-app',
#    'url': 'https://api.github.com/repos/JoshuaKGoldberg/create-typescript-app'},
#   'payload': {'ref': 'renovate/typescript-eslint-monorepo',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896059',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 857283005,
#    'name': 'shirokovnv/agate',
#    'url': 'https://api.github.com/repos/shirokovnv/agate'},
#   'payload': {'ref': 'dependabot/composer/laravel/framework-11.35.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'API Gateway written with PHP and Laravel Framework.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'},
#  {'id': '44838896057',
#   'type': 'CreateEvent',
#   'actor': {'id': 182360411,
#    'login': 'Mashabiki',
#    'display_login': 'Mashabiki',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mashabiki',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/182360411?'},
#   'repo': {'id': 904361570,
#    'name': 'Mashabiki/Mashabiki.Rasm-library-management.com',
#    'url': 'https://api.github.com/repos/Mashabiki/Mashabiki.Rasm-library-management.com'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:33:35Z'}]

# %% [markdown]
# ### Utilizando os endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ### Obtendo dados dos repositorios

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2024-10-28T21:35:35Z',
#   'pushed_at': '2024-10-18T22:23:05Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 24,
#   'stargazers_count': 14,
#   'watchers_count': 14,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 359,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 359,
#   'open_issues': 3,
#   'watchers': 14,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2024-12-03T21:53:49Z',
#   'pushed_at': '2024-07-18T14:40:53Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 370,
#   'stargazers_count': 98,
#   'watchers_count': 98,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 32,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 31,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 32,
#   'open_issues': 31,
#   'watchers': 98,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2024-09-05T08:32:25Z',
#   'pushed_at': '2024-06-03T16:53:23Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 165,
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 3,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2024-07-11T01:03:40Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 25,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 25,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2024-08-04T00:31:19Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1135,
#   'watchers_count': 1135,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1040,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1040,
#   'open_issues': 11,
#   'watchers': 1135,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2024-05-30T21:19:04Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 9,
#   'watchers_count': 9,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 4,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 4,
#   'open_issues': 0,
#   'watchers': 9,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2024-09-14T07:43:36Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 93,
#   'watchers_count': 93,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 66,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 66,
#   'open_issues': 14,
#   'watchers': 93,
#   'default_branch': 'master'},
#  {'id': 429297502,
#   'node_id': 'R_kgDOGZaPXg',
#   'name': 'amazon-codeguru-profiler-for-spark',
#   'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'description': 'A Spark plugin for CPU and memory profiling',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/deployments',
#   'created_at': '2021-11-18T04:37:55Z',
#   'updated_at': '2024-10-01T18:04:47Z',
#   'pushed_at': '2024-05-30T18:52:25Z',
#   'git_url': 'git://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'ssh_url': 'git@github.com:amzn/amazon-codeguru-profiler-for-spark.git',
#   'clone_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'svn_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'homepage': '',
#   'size': 2352,
#   'stargazers_count': 18,
#   'watchers_count': 18,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 12,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
# ...
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/deployments',
#   'created_at': '2014-12-06T01:01:38Z',
#   'updated_at': '2024-07-13T00:52:34Z',
#   'pushed_at': '2024-05-30T18:46:45Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-csharp.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'homepage': 'https://payments.amazon.com/developer',
#   'size': 28264,
#   'stargazers_count': 48,
#   'watchers_count': 48,
#   'language': 'C#',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 42,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 12,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 42,
#   'open_issues': 12,
#   'watchers': 48,
#   'default_branch': 'master'},
#  {'id': 27605347,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzYwNTM0Nw==',
#   'name': 'amazon-pay-sdk-java',
#   'full_name': 'amzn/amazon-pay-sdk-java',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'description': ' Amazon Pay Java SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/deployments',
#   'created_at': '2014-12-05T18:51:43Z',
#   'updated_at': '2024-09-09T14:17:34Z',
#   'pushed_at': '2024-08-10T17:28:22Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-java.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-java.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-java.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 13957,
#   'stargazers_count': 58,
#   'watchers_count': 58,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 51,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 15,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 51,
#   'open_issues': 15,
#   'watchers': 58,
#   'default_branch': 'master'},
#  {'id': 26331269,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjMzMTI2OQ==',
#   'name': 'amazon-pay-sdk-php',
#   'full_name': 'amzn/amazon-pay-sdk-php',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'description': 'Amazon Pay PHP SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/deployments',
#   'created_at': '2014-11-07T18:00:47Z',
#   'updated_at': '2024-09-17T15:30:38Z',
#   'pushed_at': '2024-05-14T13:04:33Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-php.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-php.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-php.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 877,
#   'stargazers_count': 208,
#   'watchers_count': 208,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 92,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 37,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 92,
#   'open_issues': 37,
#   'watchers': 208,
#   'default_branch': 'master'}]

# %%
len(response.json())
# Out:
# 30
