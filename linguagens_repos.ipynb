# %% [markdown]
# # Conhecendo a requests

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"44838635085","type":"PushEvent","actor":{"id":65984413,"login":"WaffleRaccoon","display_login":"WaffleRaccoon","gravatar_id":"","url":"https://api.github.com/users/WaffleRaccoon","avatar_url":"https://avatars.githubusercontent.com/u/65984413?"},"repo":{"id":904298459,"name":"WaffleRaccoon/Showcase-Hub","url":"https://api.github.com/repos/WaffleRaccoon/Showcase-Hub"},"payload":{"repository_id":904298459,"push_id":21735022912,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"7c1973b04ec391764dfbaf3fdf52319d4f89ba30","before":"223119baef56c800bb24c7738f214698d738fe1d","commits":[{"sha":"7c1973b04ec391764dfbaf3fdf52319d4f89ba30","author":{"email":"65984413+WaffleRaccoon@users.noreply.github.com","name":"WaffleRaccoon"},"message":"Update script.js","distinct":true,"url":"https://api.github.com/repos/WaffleRaccoon/Showcase-Hub/commits/7c1973b04ec391764dfbaf3fdf52319d4f89ba30"}]},"public":true,"created_at":"2024-12-16T18:24:59Z"},{"id":"44838635074","type":"PushEvent","actor":{"id":188305372,"login":"th3g00dpeople","display_login":"th3g00dpeople","gravatar_id":"","url":"https://api.github.com/users/th3g00dpeople","avatar_url":"https://avatars.githubusercontent.com/u/188305372?"},"repo":{"id":887749156,"name":"th3g00dpeople/th3g00dpeople.github.io","url":"https://api.github.com/repos/th3g00dpeople/th3g00dpeople.github.io"},"payload":{"repository_id":887749156,"push_id":21735022849,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"a89f9d812c97d816e323c887d1b258066ef83704","before":"d4abb8e742a4ec80af13c2cce7fcd3132ff1eaf0","commits":[{"sha":"a89f9d812c97d816e323c887d1b258066ef83704","author":{"email":"th3g00dpeople@gmail.com","name":"th3g00dpeople"},"message":"Update power-to-the-silver.html","distinct":true,"url":"https://api.github.com/repos/th3g00dpeople/th3g00dpeople.github.io/commits/a89f9d812c97d816e323c887d1b258066ef83704"}]},"public":true,"created_at":"2024-12-16T18:24:59Z"},{"id":"44838635111","type":"CreateEvent","actor":{"id":191905047,"login":"daryanabavi","display_login":"daryanabavi","gravatar_id":"","url":"https://api.github.com/users/daryanabavi","avatar_url":"https://avatars.githubusercontent.com/u/191905047?"},"repo":{"id":904358084,"name":"daryanabavi/da","url":"https://api.github.com/repos/daryanabavi/da"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2024-12-16T18:24:59Z"},{"id":"44838635065","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":695549386,"name":"YGuang233/friends-rss-generator","url":"https://api.github.com/repos/YGuang233/friends-rss-generator"},"payload":{"repository_id":695549386,"push_id":21735022795,"size":1,"distinct_size":1,"ref":"refs/heads/output","head":"7dfe8552a953d337c4d4ac1dc0bf315ef2f026b3","before":"b7cbc57397cd2fb503c8254b469d183f8f44dfab","commits":[{"sha":"7dfe8552a953d337c4d4ac1dc0bf315ef2f026b3","author":{"email":"github-actions[bot]@noreply.github.com","name":"github-actions[bot]"},"message":"Generate Json","distinct":true,"url":"https://api.github.com/repos/YGuang233/friends-rss-generator/commits/7dfe8552a953d337c4d4ac1dc0bf315ef2f026b3"}]},"public":true,"created_at":"2024-12-16T18:24:59Z"},{"id":"44838635079","type":"PushEvent","actor":{"id":146423539,"login":"namthuan2304","display_login":"namthuan2304","gravatar_id":"","url":"https://api.github.com/users/namthuan2304","avatar_url":"https://avatars.githubusercontent.com/u/146423539?"},"repo":{"id":881379711,"name":"namthuan2304/ATBMHTTT","url":"https://api.github.com/repos/namthuan2304/ATBMHTTT"},"payload":{"repository_id":881379711,"push_id":21735022884,"size":0,"distinct_size":0,"ref":"refs/heads/main","head":"0e8e95c1c163335f81a4fdad6cc189bed0c4c9d8","before":"398b25189e3f2e6a8cf18f51a9aadb50a36663a2","co ...

# %%
r.json()
# Out:
# [{'id': '44838635085',
#   'type': 'PushEvent',
#   'actor': {'id': 65984413,
#    'login': 'WaffleRaccoon',
#    'display_login': 'WaffleRaccoon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WaffleRaccoon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65984413?'},
#   'repo': {'id': 904298459,
#    'name': 'WaffleRaccoon/Showcase-Hub',
#    'url': 'https://api.github.com/repos/WaffleRaccoon/Showcase-Hub'},
#   'payload': {'repository_id': 904298459,
#    'push_id': 21735022912,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7c1973b04ec391764dfbaf3fdf52319d4f89ba30',
#    'before': '223119baef56c800bb24c7738f214698d738fe1d',
#    'commits': [{'sha': '7c1973b04ec391764dfbaf3fdf52319d4f89ba30',
#      'author': {'email': '65984413+WaffleRaccoon@users.noreply.github.com',
#       'name': 'WaffleRaccoon'},
#      'message': 'Update script.js',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/WaffleRaccoon/Showcase-Hub/commits/7c1973b04ec391764dfbaf3fdf52319d4f89ba30'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635074',
#   'type': 'PushEvent',
#   'actor': {'id': 188305372,
#    'login': 'th3g00dpeople',
#    'display_login': 'th3g00dpeople',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/th3g00dpeople',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/188305372?'},
#   'repo': {'id': 887749156,
#    'name': 'th3g00dpeople/th3g00dpeople.github.io',
#    'url': 'https://api.github.com/repos/th3g00dpeople/th3g00dpeople.github.io'},
#   'payload': {'repository_id': 887749156,
#    'push_id': 21735022849,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a89f9d812c97d816e323c887d1b258066ef83704',
#    'before': 'd4abb8e742a4ec80af13c2cce7fcd3132ff1eaf0',
#    'commits': [{'sha': 'a89f9d812c97d816e323c887d1b258066ef83704',
#      'author': {'email': 'th3g00dpeople@gmail.com', 'name': 'th3g00dpeople'},
#      'message': 'Update power-to-the-silver.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/th3g00dpeople/th3g00dpeople.github.io/commits/a89f9d812c97d816e323c887d1b258066ef83704'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635111',
#   'type': 'CreateEvent',
#   'actor': {'id': 191905047,
#    'login': 'daryanabavi',
#    'display_login': 'daryanabavi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/daryanabavi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/191905047?'},
#   'repo': {'id': 904358084,
#    'name': 'daryanabavi/da',
#    'url': 'https://api.github.com/repos/daryanabavi/da'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635065',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 695549386,
#    'name': 'YGuang233/friends-rss-generator',
#    'url': 'https://api.github.com/repos/YGuang233/friends-rss-generator'},
#   'payload': {'repository_id': 695549386,
#    'push_id': 21735022795,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '7dfe8552a953d337c4d4ac1dc0bf315ef2f026b3',
#    'before': 'b7cbc57397cd2fb503c8254b469d183f8f44dfab',
#    'commits': [{'sha': '7dfe8552a953d337c4d4ac1dc0bf315ef2f026b3',
#      'author': {'email': 'github-actions[bot]@noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Generate Json',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/YGuang233/friends-rss-generator/commits/7dfe8552a953d337c4d4ac1dc0bf315ef2f026b3'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635079',
#   'type': 'PushEvent',
#   'actor': {'id': 146423539,
#    'login': 'namthuan2304',
#    'display_login': 'namthuan2304',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/namthuan2304',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/146423539?'},
#   'repo': {'id': 881379711,
#    'name': 'namthuan2304/ATBMHTTT',
#    'url': 'https://api.github.com/repos/namthuan2304/ATBMHTTT'},
#   'payload': {'repository_id': 881379711,
#    'push_id': 21735022884,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/main',
#    'head': '0e8e95c1c163335f81a4fdad6cc189bed0c4c9d8',
#    'before': '398b25189e3f2e6a8cf18f51a9aadb50a36663a2',
#    'commits': []},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635049',
#   'type': 'PushEvent',
#   'actor': {'id': 150999554,
#    'login': 'eltenZ',
#    'display_login': 'eltenZ',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eltenZ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/150999554?'},
#   'repo': {'id': 897324109,
#    'name': 'eltenZ/Openstays',
#    'url': 'https://api.github.com/repos/eltenZ/Openstays'},
#   'payload': {'repository_id': 897324109,
#    'push_id': 21735022811,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '333b129666d228354ebe0d2871f7896b68ddb37d',
#    'before': '23d8850a1edfe3dc25694beae2cd3f140a90f68d',
#    'commits': [{'sha': '333b129666d228354ebe0d2871f7896b68ddb37d',
#      'author': {'email': 'shemwat04@gmail.com', 'name': 'eltenz'},
#      'message': 'Intriduced tailwindcss',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eltenZ/Openstays/commits/333b129666d228354ebe0d2871f7896b68ddb37d'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635069',
#   'type': 'CreateEvent',
#   'actor': {'id': 191905047,
#    'login': 'daryanabavi',
#    'display_login': 'daryanabavi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/daryanabavi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/191905047?'},
#   'repo': {'id': 904358084,
#    'name': 'daryanabavi/da',
#    'url': 'https://api.github.com/repos/daryanabavi/da'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635041',
#   'type': 'PushEvent',
#   'actor': {'id': 11367790,
#    'login': 'kforeverisback',
#    'display_login': 'kforeverisback',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kforeverisback',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11367790?'},
#   'repo': {'id': 511624281,
#    'name': 'kforeverisback/check-crlf-extended',
#    'url': 'https://api.github.com/repos/kforeverisback/check-crlf-extended'},
#   'payload': {'repository_id': 511624281,
#    'push_id': 21735022889,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b303ad54d2f130ba599597865054ed0cad0f7814',
#    'before': '26dc37a54f05cd750c0f868293c4d6718d10f6bb',
#    'commits': [{'sha': 'b303ad54d2f130ba599597865054ed0cad0f7814',
#      'author': {'email': 'mekram@microsoft.com', 'name': 'Kushal Azim Ekram'},
#      'message': 'fix: Forgot to add bash-logger script',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kforeverisback/check-crlf-extended/commits/b303ad54d2f130ba599597865054ed0cad0f7814'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635062',
#   'type': 'CreateEvent',
#   'actor': {'id': 166221506,
#    'login': 'GHrithik',
#    'display_login': 'GHrithik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GHrithik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166221506?'},
#   'repo': {'id': 904358079,
#    'name': 'GHrithik/CODESOFT',
#    'url': 'https://api.github.com/repos/GHrithik/CODESOFT'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635053',
#   'type': 'PushEvent',
#   'actor': {'id': 158243242,
#    'login': 'devin-ai-integration[bot]',
#    'display_login': 'devin-ai-integration',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/devin-ai-integration[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/158243242?'},
#   'repo': {'id': 904244175,
#    'name': 'ai-primitives/mdxe',
#    'url': 'https://api.github.com/repos/ai-primitives/mdxe'},
#   'payload': {'repository_id': 904244175,
#    'push_id': 21735022779,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/devin/1734371822-style-overrides',
#    'head': '6cc896f51a63c301c62a97bba0832902d7dafd17',
#    'before': '9a672a6c32a88805a0c32ff405b62a39c0fce4f3',
#    'commits': [{'sha': '6cc896f51a63c301c62a97bba0832902d7dafd17',
#      'author': {'email': '158243242+devin-ai-integration[bot]@users.noreply.github.com',
#       'name': 'Devin AI'},
#      'message': 'fix: update webpack configuration types for Next.js compatibility\n\nCo-Authored-By: Nathan Clevenger <nateclev@gmail.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ai-primitives/mdxe/commits/6cc896f51a63c301c62a97bba0832902d7dafd17'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z',
#   'org': {'id': 188572575,
#    'login': 'ai-primitives',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ai-primitives',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/188572575?'}},
#  {'id': '44838635051',
#   'type': 'PushEvent',
#   'actor': {'id': 104797704,
#    'login': 'taylorvnoj',
#    'display_login': 'taylorvnoj',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/taylorvnoj',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104797704?'},
#   'repo': {'id': 153540246,
#    'name': 'GetJobber/atlantis',
#    'url': 'https://api.github.com/repos/GetJobber/atlantis'},
#   'payload': {'repository_id': 153540246,
#    'push_id': 21735022855,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/JOB-90623/JOB-111325/slash-key-trigger-search',
#    'head': '5517c7e575d39048dd214b593d3aaf10afc980fe',
#    'before': 'fe7737f47921db52c7b5d64e64802f4f2d29d213',
#    'commits': [{'sha': '5517c7e575d39048dd214b593d3aaf10afc980fe',
#      'author': {'email': 'taylor.n@getjobber.com', 'name': 'Taylor Noj'},
#      'message': 'add proper focus state to button',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GetJobber/atlantis/commits/5517c7e575d39048dd214b593d3aaf10afc980fe'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z',
#   'org': {'id': 1251449,
#    'login': 'GetJobber',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/GetJobber',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1251449?'}},
#  {'id': '44838635040',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 681849187,
#    'name': 'starpause/near-nft-owners-list',
#    'url': 'https://api.github.com/repos/starpause/near-nft-owners-list'},
#   'payload': {'repository_id': 681849187,
#    'push_id': 21735022892,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '44e070ed89925e05f96a970b89211b44a21f8b0c',
#    'before': '50fce4be4de918e52e7f4f5a3afe88f176544a40',
#    'commits': [{'sha': '44e070ed89925e05f96a970b89211b44a21f8b0c',
#      'author': {'email': 'starpause@users.noreply.github.com',
#       'name': 'NFT Owners Updater'},
#      'message': 'NFT Owners fetching',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/starpause/near-nft-owners-list/commits/44e070ed89925e05f96a970b89211b44a21f8b0c'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635023',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 522892837,
#    'name': 'guptaanmol184/guptaanmol184-jessfraz',
#    'url': 'https://api.github.com/repos/guptaanmol184/guptaanmol184-jessfraz'},
#   'payload': {'repository_id': 522892837,
#    'push_id': 21735022788,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c99da2c7a31097e218efb75d7a78bc00b2a95ef0',
#    'before': '7c61c927bfdbaece9781b8a4bee3b8f9bf2bb518',
#    'commits': [{'sha': 'c99da2c7a31097e218efb75d7a78bc00b2a95ef0',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update achievements.svg - [Skip GitHub Action]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/guptaanmol184/guptaanmol184-jessfraz/commits/c99da2c7a31097e218efb75d7a78bc00b2a95ef0'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635038',
#   'type': 'PushEvent',
#   'actor': {'id': 138821450,
#    'login': 'AmiraAshreef',
#    'display_login': 'AmiraAshreef',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AmiraAshreef',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/138821450?'},
#   'repo': {'id': 894083097,
#    'name': 'AmiraAshreef/extern-black-ops-6',
#    'url': 'https://api.github.com/repos/AmiraAshreef/extern-black-ops-6'},
#   'payload': {'repository_id': 894083097,
#    'push_id': 21735022844,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e3431146a675df7ee4b5bf25175f634325a5df65',
#    'before': '2f6dd4b3619e0c01ffac2c4f7add167c50abb9ff',
#    'commits': [{'sha': 'e3431146a675df7ee4b5bf25175f634325a5df65',
#      'author': {'email': '138821450+AmiraAshreef@users.noreply.github.com',
#       'name': 'AmiraAshreef'},
#      'message': 'Merge caching issue in API responses',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AmiraAshreef/extern-black-ops-6/commits/e3431146a675df7ee4b5bf25175f634325a5df65'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635004',
#   'type': 'PushEvent',
#   'actor': {'id': 180912386,
#    'login': 'Primahesa',
#    'display_login': 'Primahesa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Primahesa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/180912386?'},
#   'repo': {'id': 879334775,
#    'name': 'Primahesa/bloxfruits-autofarm-script',
#    'url': 'https://api.github.com/repos/Primahesa/bloxfruits-autofarm-script'},
#   'payload': {'repository_id': 879334775,
#    'push_id': 21735022842,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b44d14b48a705c829feda1074435b873b073225a',
#    'before': '9351cb8416eeb769be4d9596cbcc69f2ec4c6d2d',
#    'commits': [{'sha': 'b44d14b48a705c829feda1074435b873b073225a',
#      'author': {'email': 'LisaNelson26021984@autorambler.ru',
#       'name': 'Primahesa'},
#      'message': 'Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Primahesa/bloxfruits-autofarm-script/commits/b44d14b48a705c829feda1074435b873b073225a'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635036',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 864192417,
#    'name': 'meegido/some-website',
#    'url': 'https://api.github.com/repos/meegido/some-website'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/typescript-eslint-8.18.1',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'breakable toy to hone my React skills and knowledge',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635045',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 641098936,
#    'name': 'loculus-project/loculus',
#    'url': 'https://api.github.com/repos/loculus-project/loculus'},
#   'payload': {'action': 'opened',
#    'number': 3445,
#    'pull_request': {'url': 'https://api.github.com/repos/loculus-project/loculus/pulls/3445',
#     'id': 2237990327,
#     'node_id': 'PR_kwDOJjZkuM6FZQW3',
#     'html_url': 'https://github.com/loculus-project/loculus/pull/3445',
#     'diff_url': 'https://github.com/loculus-project/loculus/pull/3445.diff',
#     'patch_url': 'https://github.com/loculus-project/loculus/pull/3445.patch',
#     'issue_url': 'https://api.github.com/repos/loculus-project/loculus/issues/3445',
#     'number': 3445,
#     'state': 'open',
#     'locked': False,
#     'title': 'chore(deps): bump react, react-dom and @types/react in /website',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'Bumps [react](https://github.com/facebook/react/tree/HEAD/packages/react), [react-dom](https://github.com/facebook/react/tree/HEAD/packages/react-dom) and [@types/react](https://github.com/DefinitelyTyped/DefinitelyTyped/tree/HEAD/types/react). These dependencies needed to be updated together.\nUpdates `react` from 18.3.1 to 19.0.0\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/facebook/react/releases">react\'s releases</a>.</em></p>\n<blockquote>\n<h2>19.0.0 (December 5, 2024)</h2>\n<p>Below is a list of all new features, APIs, deprecations, and breaking changes. Read <a href="https://react.dev/blog/2024/04/25/react-19">React 19 release post</a> and <a href="https://react.dev/blog/2024/04/25/react-19-upgrade-guide">React 19 upgrade guide</a> for more information.</p>\n<blockquote>\n<p>Note: To help make the upgrade to React 19 easier, we’ve published a react@18.3 release that is identical to 18.2 but adds warnings for deprecated APIs and other changes that are needed for React 19. We recommend upgrading to React 18.3.1 first to help identify any issues before upgrading to React 19.</p>\n</blockquote>\n<h2>New Features</h2>\n<h3>React</h3>\n<ul>\n<li>Actions: <code>startTransition</code> can now accept async functions. Functions passed to <code>startTransition</code> are called “Actions”. A given Transition can include one or more Actions which update state in the background and update the UI with one commit. In addition to updating state, Actions can now perform side effects including async requests, and the Action will wait for the work to finish before finishing the Transition. This feature allows Transitions to include side effects like <code>fetch()</code> in the pending state, and provides support for error handling, and optimistic updates.</li>\n<li><code>useActionState</code>: is a new hook to order Actions inside of a Transition with access to the state of the action, and the pending state. It accepts a reducer that can call Actions, and the initial state used for first render. It also accepts an optional string that is used if the action is passed to a form <code>action</code> prop to support progressive enhancement in forms.</li>\n<li><code>useOptimistic</code>: is a new hook to update state while a Transition is in progress. It returns the state, and a set function that can be called inside a transition to “optimistically” update the state to expected final value immediately while the Transition completes in the background. When the transition finishes, the state is updated to the new value.</li>\n<li><code>use</code>: is a new API that allows reading resources in render. In React 19, <code>use</code> accepts a promise or Context. If provided a promise, <code>use</code> will suspend until a value is resolved. <code>use</code> can only be used in render but can be called conditionally.</li>\n<li><code>ref</code> as a prop: Refs can now be used as props, removing the need for <code>forwardRef</code>.</li>\n<li><strong>Suspense sibling pre-warming</strong>: When a component suspends, React will immediately commit the fallback of the nearest Suspense boundary, without waiting for the entire sibling tree to render. After the fallback commits, React will schedule another render for the suspended siblings to “pre-warm” lazy requests.</li>\n</ul>\n<h3>React DOM Client</h3>\n<ul>\n<li><code>&lt;form&gt; action</code> prop: Form Actions allow you to manage forms automatically and integrate with <code>useFormStatus</code>. When a <code>&lt;form&gt; action</code> succeeds, React will automatically reset the form for uncontrolled components. The form can be reset manually with the new <code>requestFormReset</code> API.</li>\n<li><code>&lt;button&gt; and &lt;input&gt; formAction</code> prop: Actions can be passed to the <code>formAction</code> prop to configure form submission behavior. This allows using different Actions depending on the input.</li>\n<li><code>useFormS ...
#     'created_at': '2024-12-16T18:24:58Z',
#     'updated_at': '2024-12-16T18:24:59Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 5700831762,
#       'node_id': 'LA_kwDOJjZkuM8AAAABU8vKEg',
#       'url': 'https://api.github.com/repos/loculus-project/loculus/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 7349221690,
#       'node_id': 'LA_kwDOJjZkuM8AAAABtgw5Og',
#       'url': 'https://api.github.com/repos/loculus-project/loculus/labels/javascript',
#       'name': 'javascript',
#       'color': '168700',
#       'default': False,
#       'description': 'Pull requests that update Javascript code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/loculus-project/loculus/pulls/3445/commits',
#     'review_comments_url': 'https://api.github.com/repos/loculus-project/loculus/pulls/3445/comments',
#     'review_comment_url': 'https://api.github.com/repos/loculus-project/loculus/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/loculus-project/loculus/issues/3445/comments',
#     'statuses_url': 'https://api.github.com/repos/loculus-project/loculus/statuses/38f735ff7114d8c745ccaf74ed96de0e9b355f59',
#     'head': {'label': 'loculus-project:dependabot/npm_and_yarn/website/multi-cec19ee5eb',
#      'ref': 'dependabot/npm_and_yarn/website/multi-cec19ee5eb',
#      'sha': '38f735ff7114d8c745ccaf74ed96de0e9b355f59',
#      'user': {'login': 'loculus-project',
#       'id': 133703674,
#       'node_id': 'O_kgDOB_gn-g',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/133703674?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/loculus-project',
#       'html_url': 'https://github.com/loculus-project',
#       'followers_url': 'https://api.github.com/users/loculus-project/followers',
#       'following_url': 'https://api.github.com/users/loculus-project/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/loculus-project/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/loculus-project/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/loculus-project/subscriptions',
#       'organizations_url': 'https://api.github.com/users/loculus-project/orgs',
#       'repos_url': 'https://api.github.com/users/loculus-project/repos',
#       'events_url': 'https://api.github.com/users/loculus-project/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/loculus-project/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 641098936,
#       'node_id': 'R_kgDOJjZkuA',
#       'name': 'loculus',
#       'full_name': 'loculus-project/loculus',
#       'private': False,
#       'owner': {'login': 'loculus-project',
#        'id': 133703674,
#        'node_id': 'O_kgDOB_gn-g',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/133703674?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/loculus-project',
#        'html_url': 'https://github.com/loculus-project',
#        'followers_url': 'https://api.github.com/users/loculus-project/followers',
#        'following_url': 'https://api.github.com/users/loculus-project/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/loculus-project/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/loculus-project/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/loculus-project/subscriptions',
#        'organizations_url': 'https://api.github.com/users/loculus-project/orgs',
#        'repos_url': 'https://api.github.com/users/loculus-project/repos',
#        'events_url': 'https://api.github.com/users/loculus-project/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/loculus-project/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/loculus-project/loculus',
#       'description': 'An open-source software package to power microbial genomic databases',
#       'fork': False,
#       'url': 'https://api.github.com/repos/loculus-project/loculus',
#       'forks_url': 'https://api.github.com/repos/loculus-project/loculus/forks',
#       'keys_url': 'https://api.github.com/repos/loculus-project/loculus/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/loculus-project/loculus/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/loculus-project/loculus/teams',
#       'hooks_url': 'https://api.github.com/repos/loculus-project/loculus/hooks',
#       'issue_events_url': 'https://api.github.com/repos/loculus-project/loculus/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/loculus-project/loculus/events',
#       'assignees_url': 'https://api.github.com/repos/loculus-project/loculus/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/loculus-project/loculus/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/loculus-project/loculus/tags',
#       'blobs_url': 'https://api.github.com/repos/loculus-project/loculus/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/loculus-project/loculus/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/loculus-project/loculus/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/loculus-project/loculus/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/loculus-project/loculus/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/loculus-project/loculus/languages',
#       'stargazers_url': 'https://api.github.com/repos/loculus-project/loculus/stargazers',
#       'contributors_url': 'https://api.github.com/repos/loculus-project/loculus/contributors',
#       'subscribers_url': 'https://api.github.com/repos/loculus-project/loculus/subscribers',
#       'subscription_url': 'https://api.github.com/repos/loculus-project/loculus/subscription',
#       'commits_url': 'https://api.github.com/repos/loculus-project/loculus/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/loculus-project/loculus/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/loculus-project/loculus/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/loculus-project/loculus/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/loculus-project/loculus/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/loculus-project/loculus/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/loculus-project/loculus/merges',
#       'archive_url': 'https://api.github.com/repos/loculus-project/loculus/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/loculus-project/loculus/downloads',
#       'issues_url': 'https://api.github.com/repos/loculus-project/loculus/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/loculus-project/loculus/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/loculus-project/loculus/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/loculus-project/loculus/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/loculus-project/loculus/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/loculus-project/loculus/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/loculus-project/loculus/deployments',
#       'created_at': '2023-05-15T19:22:09Z',
#       'updated_at': '2024-12-12T16:39:08Z',
#       'pushed_at': '2024-12-16T18:24:57Z',
#       'git_url': 'git://github.com/loculus-project/loculus.git',
#       'ssh_url': 'git@github.com:loculus-project/loculus.git',
#       'clone_url': 'https://github.com/loculus-project/loculus.git',
#       'svn_url': 'https://github.com/loculus-project/loculus',
#       'homepage': 'https://loculus.org',
#       'size': 32814,
#       'stargazers_count': 41,
#       'watchers_count': 41,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'has_discussions': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 477,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 2,
#       'open_issues': 477,
#       'watchers': 41,
#       'default_branch': 'main'}},
#     'base': {'label': 'loculus-project:main',
#      'ref': 'main',
#      'sha': 'd3505b76aa45ef278868c63c55f5d040a29d42c1',
#      'user': {'login': 'loculus-project',
#       'id': 133703674,
#       'node_id': 'O_kgDOB_gn-g',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/133703674?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/loculus-project',
#       'html_url': 'https://github.com/loculus-project',
#       'followers_url': 'https://api.github.com/users/loculus-project/followers',
#       'following_url': 'https://api.github.com/users/loculus-project/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/loculus-project/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/loculus-project/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/loculus-project/subscriptions',
#       'organizations_url': 'https://api.github.com/users/loculus-project/orgs',
#       'repos_url': 'https://api.github.com/users/loculus-project/repos',
#       'events_url': 'https://api.github.com/users/loculus-project/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/loculus-project/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 641098936,
#       'node_id': 'R_kgDOJjZkuA',
#       'name': 'loculus',
#       'full_name': 'loculus-project/loculus',
#       'private': False,
#       'owner': {'login': 'loculus-project',
#        'id': 133703674,
#        'node_id': 'O_kgDOB_gn-g',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/133703674?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/loculus-project',
#        'html_url': 'https://github.com/loculus-project',
#        'followers_url': 'https://api.github.com/users/loculus-project/followers',
#        'following_url': 'https://api.github.com/users/loculus-project/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/loculus-project/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/loculus-project/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/loculus-project/subscriptions',
#        'organizations_url': 'https://api.github.com/users/loculus-project/orgs',
#        'repos_url': 'https://api.github.com/users/loculus-project/repos',
#        'events_url': 'https://api.github.com/users/loculus-project/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/loculus-project/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/loculus-project/loculus',
#       'description': 'An open-source software package to power microbial genomic databases',
#       'fork': False,
#       'url': 'https://api.github.com/repos/loculus-project/loculus',
#       'forks_url': 'https://api.github.com/repos/loculus-project/loculus/forks',
#       'keys_url': 'https://api.github.com/repos/loculus-project/loculus/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/loculus-project/loculus/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/loculus-project/loculus/teams',
#       'hooks_url': 'https://api.github.com/repos/loculus-project/loculus/hooks',
#       'issue_events_url': 'https://api.github.com/repos/loculus-project/loculus/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/loculus-project/loculus/events',
#       'assignees_url': 'https://api.github.com/repos/loculus-project/loculus/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/loculus-project/loculus/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/loculus-project/loculus/tags',
#       'blobs_url': 'https://api.github.com/repos/loculus-project/loculus/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/loculus-project/loculus/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/loculus-project/loculus/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/loculus-project/loculus/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/loculus-project/loculus/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/loculus-project/loculus/languages',
#       'stargazers_url': 'https://api.github.com/repos/loculus-project/loculus/stargazers',
#       'contributors_url': 'https://api.github.com/repos/loculus-project/loculus/contributors',
#       'subscribers_url': 'https://api.github.com/repos/loculus-project/loculus/subscribers',
#       'subscription_url': 'https://api.github.com/repos/loculus-project/loculus/subscription',
#       'commits_url': 'https://api.github.com/repos/loculus-project/loculus/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/loculus-project/loculus/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/loculus-project/loculus/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/loculus-project/loculus/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/loculus-project/loculus/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/loculus-project/loculus/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/loculus-project/loculus/merges',
#       'archive_url': 'https://api.github.com/repos/loculus-project/loculus/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/loculus-project/loculus/downloads',
#       'issues_url': 'https://api.github.com/repos/loculus-project/loculus/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/loculus-project/loculus/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/loculus-project/loculus/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/loculus-project/loculus/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/loculus-project/loculus/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/loculus-project/loculus/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/loculus-project/loculus/deployments',
#       'created_at': '2023-05-15T19:22:09Z',
#       'updated_at': '2024-12-12T16:39:08Z',
#       'pushed_at': '2024-12-16T18:24:57Z',
#       'git_url': 'git://github.com/loculus-project/loculus.git',
#       'ssh_url': 'git@github.com:loculus-project/loculus.git',
#       'clone_url': 'https://github.com/loculus-project/loculus.git',
#       'svn_url': 'https://github.com/loculus-project/loculus',
#       'homepage': 'https://loculus.org',
#       'size': 32814,
#       'stargazers_count': 41,
#       'watchers_count': 41,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'has_discussions': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 477,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 2,
#       'open_issues': 477,
#       'watchers': 41,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/loculus-project/loculus/pulls/3445'},
#      'html': {'href': 'https://github.com/loculus-project/loculus/pull/3445'},
#      'issue': {'href': 'https://api.github.com/repos/loculus-project/loculus/issues/3445'},
#      'comments': {'href': 'https://api.github.com/repos/loculus-project/loculus/issues/3445/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/loculus-project/loculus/pulls/3445/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/loculus-project/loculus/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/loculus-project/loculus/pulls/3445/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/loculus-project/loculus/statuses/38f735ff7114d8c745ccaf74ed96de0e9b355f59'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 134,
#     'deletions': 117,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z',
#   'org': {'id': 133703674,
#    'login': 'loculus-project',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/loculus-project',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/133703674?'}},
#  {'id': '44838635000',
#   'type': 'PushEvent',
#   'actor': {'id': 85067674,
#    'login': 'mariazoom',
#    'display_login': 'mariazoom',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mariazoom',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/85067674?'},
#   'repo': {'id': 904338447,
#    'name': 'mariazoom/QuantumMetrics',
#    'url': 'https://api.github.com/repos/mariazoom/QuantumMetrics'},
#   'payload': {'repository_id': 904338447,
#    'push_id': 21735022725,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'dc4d2a89acbc39bf03bfca244a0a6f8a1a92763b',
#    'before': 'a65b50a4a2d070e5ca7e49b3004f4fdfd3d4eac5',
#    'commits': [{'sha': 'dc4d2a89acbc39bf03bfca244a0a6f8a1a92763b',
#      'author': {'email': 'zuoeiasffo@rambler.ru', 'name': 'mariazoom'},
#      'message': '',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mariazoom/QuantumMetrics/commits/dc4d2a89acbc39bf03bfca244a0a6f8a1a92763b'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635007',
#   'type': 'PushEvent',
#   'actor': {'id': 97433258,
#    'login': 'iniadittt',
#    'display_login': 'iniadittt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iniadittt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97433258?'},
#   'repo': {'id': 800371228,
#    'name': 'iniadittt/iniadittt',
#    'url': 'https://api.github.com/repos/iniadittt/iniadittt'},
#   'payload': {'repository_id': 800371228,
#    'push_id': 21735022833,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ab755b54be8e703a80ec5fff93e2f48beebb92d8',
#    'before': 'acdb4950330866a7f5d1476e9424b5b14f110bc2',
#    'commits': [{'sha': 'ab755b54be8e703a80ec5fff93e2f48beebb92d8',
#      'author': {'email': 'aditya.braincore@gmail.com', 'name': 'iniadittt'},
#      'message': 'UPDATE',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/iniadittt/iniadittt/commits/ab755b54be8e703a80ec5fff93e2f48beebb92d8'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838635016',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 785205460,
#    'name': 'SUGAM-ARORA/DriveEasy',
#    'url': 'https://api.github.com/repos/SUGAM-ARORA/DriveEasy'},
#   'payload': {'action': 'opened',
#    'number': 38,
#    'pull_request': {'url': 'https://api.github.com/repos/SUGAM-ARORA/DriveEasy/pulls/38',
#     'id': 2237990314,
#     'node_id': 'PR_kwDOLs1I1M6FZQWq',
#     'html_url': 'https://github.com/SUGAM-ARORA/DriveEasy/pull/38',
#     'diff_url': 'https://github.com/SUGAM-ARORA/DriveEasy/pull/38.diff',
#     'patch_url': 'https://github.com/SUGAM-ARORA/DriveEasy/pull/38.patch',
#     'issue_url': 'https://api.github.com/repos/SUGAM-ARORA/DriveEasy/issues/38',
#     'number': 38,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump springsecurity.version from 6.4.1 to 6.4.2',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
# ...
#    'url': 'https://api.github.com/repos/cloudfoundry/bosh-io-releases-index'},
#   'payload': {'repository_id': 102677805,
#    'push_id': 21735022594,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '16a2187a355397240117e737b5c184687fad9dd0',
#    'before': '0e24cf5d02b338abe78452b489d90c7f2dca1e1b',
#    'commits': [{'sha': '16a2187a355397240117e737b5c184687fad9dd0',
#      'author': {'email': 'bosh-io-worker', 'name': 'bosh-io-worker'},
#      'message': 'add mapfs-1.13.0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cloudfoundry/bosh-io-releases-index/commits/16a2187a355397240117e737b5c184687fad9dd0'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z',
#   'org': {'id': 621746,
#    'login': 'cloudfoundry',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cloudfoundry',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/621746?'}},
#  {'id': '44838634968',
#   'type': 'PushEvent',
#   'actor': {'id': 17952060,
#    'login': 'RichardLechko',
#    'display_login': 'RichardLechko',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RichardLechko',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17952060?'},
#   'repo': {'id': 839173520,
#    'name': 'RichardLechko/React-Resume',
#    'url': 'https://api.github.com/repos/RichardLechko/React-Resume'},
#   'payload': {'repository_id': 839173520,
#    'push_id': 21735022701,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fb923024cc933eb83990c05f68b16d31d9bfbc1a',
#    'before': '601ef5665e2ac256f82b86641af0f98a1542febe',
#    'commits': [{'sha': 'fb923024cc933eb83990c05f68b16d31d9bfbc1a',
#      'author': {'email': 'richardlechko04@gmail.com', 'name': 'RichardLechko'},
#      'message': 'changed styling',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RichardLechko/React-Resume/commits/fb923024cc933eb83990c05f68b16d31d9bfbc1a'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838634955',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 780439892,
#    'name': 'imowa/lava',
#    'url': 'https://api.github.com/repos/imowa/lava'},
#   'payload': {'repository_id': 780439892,
#    'push_id': 21735022739,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'eeb983c5047ca6dce86aa12345e371951ca81769',
#    'before': 'b53165e9c2dcf3dc03ed02fffc70650929c7d133',
#    'commits': [{'sha': 'eeb983c5047ca6dce86aa12345e371951ca81769',
#      'author': {'email': 'rxmxdhxni@gmail.com', 'name': 'dante4rt'},
#      'message': '📦 Update StarkNet network',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/imowa/lava/commits/eeb983c5047ca6dce86aa12345e371951ca81769'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838634976',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 73139402,
#    'login': 'cloudflare-workers-and-pages[bot]',
#    'display_login': 'cloudflare-workers-and-pages',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cloudflare-workers-and-pages[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73139402?'},
#   'repo': {'id': 201442335,
#    'name': 'arlac77/svelte-session-manager',
#    'url': 'https://api.github.com/repos/arlac77/svelte-session-manager'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/arlac77/svelte-session-manager/issues/3146',
#     'repository_url': 'https://api.github.com/repos/arlac77/svelte-session-manager',
#     'labels_url': 'https://api.github.com/repos/arlac77/svelte-session-manager/issues/3146/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/arlac77/svelte-session-manager/issues/3146/comments',
#     'events_url': 'https://api.github.com/repos/arlac77/svelte-session-manager/issues/3146/events',
#     'html_url': 'https://github.com/arlac77/svelte-session-manager/pull/3146',
#     'id': 2743088993,
#     'node_id': 'PR_kwDODAHEH86FZQV0',
#     'number': 3146,
#     'title': 'Regenerate package lock',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [{'id': 3147643078,
#       'node_id': 'MDU6TGFiZWwzMTQ3NjQzMDc4',
#       'url': 'https://api.github.com/repos/arlac77/svelte-session-manager/labels/npm',
#       'name': 'npm',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2024-12-16T18:24:55Z',
#     'updated_at': '2024-12-16T18:24:59Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/arlac77/svelte-session-manager/pulls/3146',
#      'html_url': 'https://github.com/arlac77/svelte-session-manager/pull/3146',
#      'diff_url': 'https://github.com/arlac77/svelte-session-manager/pull/3146.diff',
#      'patch_url': 'https://github.com/arlac77/svelte-session-manager/pull/3146.patch',
#      'merged_at': None},
#     'body': 'bring lock in sync',
#     'reactions': {'url': 'https://api.github.com/repos/arlac77/svelte-session-manager/issues/3146/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/arlac77/svelte-session-manager/issues/3146/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/arlac77/svelte-session-manager/issues/comments/2546340855',
#     'html_url': 'https://github.com/arlac77/svelte-session-manager/pull/3146#issuecomment-2546340855',
#     'issue_url': 'https://api.github.com/repos/arlac77/svelte-session-manager/issues/3146',
#     'id': 2546340855,
#     'node_id': 'IC_kwDODAHEH86XxhP3',
#     'user': {'login': 'cloudflare-workers-and-pages[bot]',
#      'id': 73139402,
#      'node_id': 'MDM6Qm90NzMxMzk0MDI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/85455?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cloudflare-workers-and-pages%5Bbot%5D',
#      'html_url': 'https://github.com/apps/cloudflare-workers-and-pages',
#      'followers_url': 'https://api.github.com/users/cloudflare-workers-and-pages%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/cloudflare-workers-and-pages%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cloudflare-workers-and-pages%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cloudflare-workers-and-pages%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cloudflare-workers-and-pages%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cloudflare-workers-and-pages%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/cloudflare-workers-and-pages%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/cloudflare-workers-and-pages%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cloudflare-workers-and-pages%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2024-12-16T18:24:58Z',
#     'updated_at': '2024-12-16T18:24:58Z',
#     'author_association': 'NONE',
#     'body': '## Deploying svelte-session-manager with &nbsp;<a href="https://pages.dev"><img alt="Cloudflare Pages" src="https://user-images.githubusercontent.com/23264/106598434-9e719e00-654f-11eb-9e59-6167043cfa01.png" width="16"></a> &nbsp;Cloudflare Pages\n\n<table><tr><td><strong>Latest commit:</strong> </td><td>\n<code>00dadad</code>\n</td></tr>\n<tr><td><strong>Status:</strong></td><td>⚡️&nbsp; Build in progress...</td></tr>\n</table>\n\n[View logs](https://dash.cloudflare.com/?to=/:account/pages/view/svelte-session-manager/33c74b83-515f-47bb-9a3e-cd98407bcda5)\n',
#     'reactions': {'url': 'https://api.github.com/repos/arlac77/svelte-session-manager/issues/comments/2546340855/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': {'id': 85455,
#      'client_id': 'Iv1.0879b6ff6c8f7a1a',
#      'slug': 'cloudflare-workers-and-pages',
#      'node_id': 'MDM6QXBwODU0NTU=',
#      'owner': {'login': 'cloudflare',
#       'id': 314135,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMxNDEzNQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/314135?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cloudflare',
#       'html_url': 'https://github.com/cloudflare',
#       'followers_url': 'https://api.github.com/users/cloudflare/followers',
#       'following_url': 'https://api.github.com/users/cloudflare/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cloudflare/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cloudflare/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cloudflare/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cloudflare/orgs',
#       'repos_url': 'https://api.github.com/users/cloudflare/repos',
#       'events_url': 'https://api.github.com/users/cloudflare/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cloudflare/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'name': 'Cloudflare Workers and Pages',
#      'description': '',
#      'external_url': 'https://cloudflare.com/',
#      'html_url': 'https://github.com/apps/cloudflare-workers-and-pages',
#      'created_at': '2020-10-19T20:23:00Z',
#      'updated_at': '2024-09-19T15:15:04Z',
#      'permissions': {'checks': 'write',
#       'contents': 'read',
#       'deployments': 'write',
#       'metadata': 'read',
#       'pull_requests': 'write'},
#      'events': ['pull_request', 'push']}}},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838634940',
#   'type': 'PushEvent',
#   'actor': {'id': 28764927,
#    'login': 'MineShadow7',
#    'display_login': 'MineShadow7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MineShadow7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28764927?'},
#   'repo': {'id': 857783643,
#    'name': 'MineShadow7/cuda-2024',
#    'url': 'https://api.github.com/repos/MineShadow7/cuda-2024'},
#   'payload': {'repository_id': 857783643,
#    'push_id': 21735022754,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev_lab4',
#    'head': '635fc9f2268b866f578cba7b37ebf492ac210712',
#    'before': '8b45c2c3c05b531afbd0f0eb57d69b238e84f01f',
#    'commits': [{'sha': '635fc9f2268b866f578cba7b37ebf492ac210712',
#      'author': {'email': 'shad-karagodin@ya.ru', 'name': 'MineShadow7'},
#      'message': 'Prepare code for task',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MineShadow7/cuda-2024/commits/635fc9f2268b866f578cba7b37ebf492ac210712'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838634925',
#   'type': 'PushEvent',
#   'actor': {'id': 47502554,
#    'login': 'lostdusty',
#    'display_login': 'lostdusty',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lostdusty',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47502554?'},
#   'repo': {'id': 904354072,
#    'name': 'data-ru/gufu',
#    'url': 'https://api.github.com/repos/data-ru/gufu'},
#   'payload': {'repository_id': 904354072,
#    'push_id': 21735022820,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fb2f8317565acbfa75fdc6bcfe3203d6b70cfec8',
#    'before': '12ed0ec29683e4da780613b814e1940f8de4ca31',
#    'commits': [{'sha': 'fb2f8317565acbfa75fdc6bcfe3203d6b70cfec8',
#      'author': {'email': '47502554+lostdusty@users.noreply.github.com',
#       'name': 'lostdusty'},
#      'message': 'fix: arrumar badges',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/data-ru/gufu/commits/fb2f8317565acbfa75fdc6bcfe3203d6b70cfec8'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z',
#   'org': {'id': 168130510,
#    'login': 'data-ru',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/data-ru',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/168130510?'}},
#  {'id': '44838634931',
#   'type': 'PushEvent',
#   'actor': {'id': 97106041,
#    'login': 'tigran-sargsyan-w',
#    'display_login': 'tigran-sargsyan-w',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tigran-sargsyan-w',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97106041?'},
#   'repo': {'id': 904355565,
#    'name': 'tigran-sargsyan-w/Libft',
#    'url': 'https://api.github.com/repos/tigran-sargsyan-w/Libft'},
#   'payload': {'repository_id': 904355565,
#    'push_id': 21735022800,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b4c9ac782604a25507b68e61a4dec1dcebe0e8b0',
#    'before': '637a488bb94d41a0360a6a13cfd9b768eede390d',
#    'commits': [{'sha': 'b4c9ac782604a25507b68e61a4dec1dcebe0e8b0',
#      'author': {'email': 'tsargsya@z1r6p1.42lyon.fr',
#       'name': 'Tigran Sargsyan'},
#      'message': '-feat:libft',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tigran-sargsyan-w/Libft/commits/b4c9ac782604a25507b68e61a4dec1dcebe0e8b0'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'},
#  {'id': '44838634922',
#   'type': 'PushEvent',
#   'actor': {'id': 157969601,
#    'login': 'sumya1509',
#    'display_login': 'sumya1509',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sumya1509',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/157969601?'},
#   'repo': {'id': 875511481,
#    'name': 'KhandakerUmmeSalma/Dbms-Inventory_Management_System',
#    'url': 'https://api.github.com/repos/KhandakerUmmeSalma/Dbms-Inventory_Management_System'},
#   'payload': {'repository_id': 875511481,
#    'push_id': 21735022710,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6089d7557e9d7b974c36342fb6594ecc485a630a',
#    'before': 'e03b700cc4e6922dac2560e4ed6d63b4b5509f49',
#    'commits': [{'sha': '6089d7557e9d7b974c36342fb6594ecc485a630a',
#      'author': {'email': '157969601+sumya1509@users.noreply.github.com',
#       'name': 'sumya1509'},
#      'message': 'Delete cart.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/KhandakerUmmeSalma/Dbms-Inventory_Management_System/commits/6089d7557e9d7b974c36342fb6594ecc485a630a'}]},
#   'public': True,
#   'created_at': '2024-12-16T18:24:59Z'}]

# %% [markdown]
# ### Utilizando os endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']
